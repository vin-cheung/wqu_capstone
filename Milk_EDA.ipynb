# %%
import pandas as pd
EU_Milk = pd.read_pickle('data/eu.pickle')
US_Milk = pd.read_pickle('data/us.pickle')
China_Milk = pd.read_pickle('data/cn.pickle')
Fred = pd.read_pickle('data/fred.pickle')

# %%
EU_Milk.plot(figsize=(30,15), title='EU Milk Price Trend')
# Out:
# <AxesSubplot:title={'center':'EU Milk Price Trend'}>

# %%
US_Milk.plot(figsize=(30,15), title='US Milk Price Trend')
# Out:
# <AxesSubplot:title={'center':'US Milk Price Trend'}, xlabel='Date'>

# %%
China_Milk.plot(figsize=(30,10), title='China Milk Price Trend')
# Out:
# <AxesSubplot:title={'center':'China Milk Price Trend'}>

# %%
EU_Milk.boxplot(figsize=(20,10), rot=90)
# Out:
# <AxesSubplot:>

# %%
US_Milk.boxplot(figsize=(20,10), rot=90)
# Out:
# <AxesSubplot:>

# %%
China_Milk.to_frame().boxplot()
# Out:
# <AxesSubplot:>
